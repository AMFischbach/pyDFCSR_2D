# %%
from csr2d import CSR2D

# %%
# %matplotlib widget
# %load_ext line_profiler
csr_2d = CSR2D(input_file= 'input/dipole_config.yaml')
csr_2d.run()
csr_2d.save_data("/Users/treyfischbach/Desktop/SULI 2024/Wake Benchmarking/data", "s0 no wakes applied 2D test")
# Out:
# CSR2D Object Succesfully Initialized
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# '\nmax_index = np.argmax(csr_2d.df_tracker.density[0])\n\n# Convert the flattened index to a 2D index\nmax_index_2d = np.unravel_index(max_index, csr_2d.df_tracker.density[0].shape)\n\nprint(max_index_2d)\nprint(csr_2d.df_tracker.h_coords[0][max_index_2d[0]-1][max_index_2d[1]-1])\n'
